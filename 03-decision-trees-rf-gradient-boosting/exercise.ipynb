# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

heart_dataset = pd.read_csv('../datasets/uci-heart-disease/heart.csv')

heart_dataset.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Split the data into input and labels
labels = heart_dataset['target']
input_data = heart_dataset.drop(columns=['target'])

# %%
input_data.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal
# 0   0     1
# 1   0     2
# 2   0     2
# 3   0     2
# 4   0     2

# %%
from sklearn.model_selection import GridSearchCV

# Note, we don't split the data. GridSearchCV will automatically apply 5-fold cross validation by default.

tuned_parameters = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [None, 3, 5, 10, 20],
    'min_samples_split': [2, 4, 8, 16, 32],
    'max_leaf_nodes': [None, 10, 20, 40, 80]
}

# These two lines will result in every possible combo of the above paramters to be fit and scored
# which can take a LONG TIME with large datasets.
clf = DecisionTreeClassifier()
grid_tree = GridSearchCV(clf, tuned_parameters)
grid_tree.fit(input_data, labels)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 3, 5, 10, 20],
#                          'max_leaf_nodes': [None, 10, 20, 40, 80],
#                          'min_samples_split': [2, 4, 8, 16, 32],
#                          'splitter': ['best', 'random']})

# %%
print("Best parameters set found on development set:")
print()
print(grid_tree.best_params_, grid_tree.best_score_)
print()
print("Grid scores on development set:")
print()
means = grid_tree.cv_results_['mean_test_score']
stds = grid_tree.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, grid_tree.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
          % (mean, std * 2, params))
# Out:
# Best parameters set found on development set:
#
# {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'random'} 0.8284153005464482
#
# Grid scores on development set:
#
# 0.756 (+/-0.119) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'best'}
# 0.752 (+/-0.068) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'random'}
# 0.746 (+/-0.118) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'best'}
# 0.743 (+/-0.110) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'random'}
# 0.779 (+/-0.082) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'best'}
# 0.795 (+/-0.110) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'random'}
# 0.752 (+/-0.108) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'best'}
# 0.795 (+/-0.107) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'random'}
# 0.792 (+/-0.071) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'best'}
# 0.756 (+/-0.050) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'random'}
# 0.795 (+/-0.115) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'best'}
# 0.825 (+/-0.051) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'random'}
# 0.795 (+/-0.115) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'best'}
# 0.785 (+/-0.068) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'random'}
# 0.799 (+/-0.106) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'best'}
# 0.772 (+/-0.028) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'random'}
# 0.775 (+/-0.125) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'best'}
# 0.792 (+/-0.051) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'random'}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'best'}
# 0.749 (+/-0.058) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'random'}
# 0.779 (+/-0.078) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 2, 'splitter': 'best'}
# 0.762 (+/-0.111) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 2, 'splitter': 'random'}
# 0.775 (+/-0.086) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'best'}
# 0.779 (+/-0.029) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'random'}
# 0.772 (+/-0.096) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 8, 'splitter': 'best'}
# 0.743 (+/-0.054) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 8, 'splitter': 'random'}
# 0.755 (+/-0.100) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 16, 'splitter': 'best'}
# 0.802 (+/-0.090) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 16, 'splitter': 'random'}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'best'}
# 0.756 (+/-0.085) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'random'}
# 0.772 (+/-0.101) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'best'}
# 0.792 (+/-0.088) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'random'}
# 0.769 (+/-0.091) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'best'}
# 0.799 (+/-0.072) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'random'}
# 0.769 (+/-0.094) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'best'}
# 0.703 (+/-0.078) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'random'}
# 0.755 (+/-0.100) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'best'}
# 0.739 (+/-0.145) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'random'}
# 0.792 (+/-0.071) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'best'}
# 0.753 (+/-0.053) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'random'}
# 0.746 (+/-0.102) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'best'}
# 0.709 (+/-0.127) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'random'}
# 0.759 (+/-0.122) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'best'}
# 0.752 (+/-0.115) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'random'}
# 0.772 (+/-0.067) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'best'}
# 0.782 (+/-0.064) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'random'}
# 0.752 (+/-0.108) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'best'}
# 0.785 (+/-0.103) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'random'}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'best'}
# 0.746 (+/-0.093) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'random'}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'best'}
# 0.805 (+/-0.038) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'random'}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'best'}
# 0.786 (+/-0.054) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'random'}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'best'}
# 0.759 (+/-0.129) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'random'}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'best'}
# 0.792 (+/-0.041) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'random'}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'best'}
# 0.769 (+/-0.153) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'random'}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'best'}
# 0.795 (+/-0.090) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'random'}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'best'}
# 0.775 (+/-0.096) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'random'}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'best'}
# 0.792 (+/-0.112) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'random'}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'best'}
# 0.766 (+/-0.051) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'random'}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'best'}
# 0.772 (+/-0.071) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'random'}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 2, 'splitter': 'best'}
# 0.763 (+/-0.074) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 2, 'splitter': 'random'}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'best'}
# 0.782 (+/-0.138) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'random'}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 8, 'splitter': 'best'}
# 0.789 (+/-0.091) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 8, 'splitter': 'random'}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 16, 'splitter': 'best'}
# 0.762 (+/-0.106) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 16, 'splitter': 'random'}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'best'}
# 0.792 (+/-0.124) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'random'}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'best'}
# 0.805 (+/-0.072) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'random'}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'best'}
# 0.795 (+/-0.129) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'random'}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'best'}
# 0.772 (+/-0.108) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'random'}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'best'}
# 0.785 (+/-0.044) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'random'}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'best'}
# 0.762 (+/-0.072) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'random'}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'best'}
# 0.752 (+/-0.094) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'random'}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'best'}
# 0.799 (+/-0.094) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'random'}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'best'}
# 0.779 (+/-0.053) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'random'}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'best'}
# 0.789 (+/-0.051) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'random'}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'best'}
# 0.795 (+/-0.087) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'random'}
# 0.782 (+/-0.071) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'best'}
# 0.769 (+/-0.084) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'random'}
# 0.779 (+/-0.102) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'best'}
# 0.769 (+/-0.109) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'random'}
# 0.782 (+/-0.088) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'best'}
# 0.755 (+/-0.093) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'random'}
# 0.759 (+/-0.104) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'best'}
# 0.789 (+/-0.034) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'random'}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'best'}
# 0.749 (+/-0.104) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'random'}
# 0.789 (+/-0.113) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'best'}
# 0.772 (+/-0.075) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'random'}
# 0.789 (+/-0.113) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'best'}
# 0.805 (+/-0.046) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'random'}
# 0.795 (+/-0.105) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'best'}
# 0.779 (+/-0.100) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'random'}
# 0.779 (+/-0.121) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'best'}
# 0.789 (+/-0.092) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'random'}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'best'}
# 0.742 (+/-0.048) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'random'}
# 0.779 (+/-0.102) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 2, 'splitter': 'best'}
# 0.779 (+/-0.133) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 2, 'splitter': 'random'}
# 0.789 (+/-0.110) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'best'}
# 0.765 (+/-0.067) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'random'}
# 0.775 (+/-0.087) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 8, 'splitter': 'best'}
# 0.769 (+/-0.098) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 8, 'splitter': 'random'}
# 0.759 (+/-0.104) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 16, 'splitter': 'best'}
# 0.782 (+/-0.083) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 16, 'splitter': 'random'}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'best'}
# 0.779 (+/-0.060) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'random'}
# 0.789 (+/-0.092) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'best'}
# 0.775 (+/-0.077) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'random'}
# 0.782 (+/-0.108) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'best'}
# 0.766 (+/-0.056) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'random'}
# 0.769 (+/-0.070) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'best'}
# 0.779 (+/-0.059) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'random'}
# 0.755 (+/-0.112) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'best'}
# 0.743 (+/-0.085) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'random'}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'best'}
# 0.749 (+/-0.098) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'random'}
# 0.779 (+/-0.096) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'best'}
# 0.785 (+/-0.058) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'random'}
# 0.789 (+/-0.077) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'best'}
# 0.769 (+/-0.031) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'random'}
# 0.779 (+/-0.080) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'best'}
# 0.785 (+/-0.055) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'random'}
# 0.759 (+/-0.104) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'best'}
# 0.789 (+/-0.070) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'random'}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'best'}
# 0.769 (+/-0.077) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'random'}
# 0.756 (+/-0.103) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'best'}
# 0.765 (+/-0.091) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'random'}
# 0.766 (+/-0.075) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'best'}
# 0.733 (+/-0.075) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'random'}
# 0.775 (+/-0.069) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'best'}
# 0.766 (+/-0.100) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'random'}
# 0.755 (+/-0.100) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'best'}
# 0.736 (+/-0.109) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'random'}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'best'}
# 0.782 (+/-0.110) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'random'}
# 0.792 (+/-0.113) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'best'}
# 0.805 (+/-0.084) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'random'}
# 0.792 (+/-0.113) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'best'}
# 0.766 (+/-0.040) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'random'}
# 0.795 (+/-0.115) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'best'}
# 0.782 (+/-0.068) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'random'}
# 0.779 (+/-0.121) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'best'}
# 0.782 (+/-0.049) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'random'}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'best'}
# 0.792 (+/-0.043) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'random'}
# 0.779 (+/-0.089) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 2, 'splitter': 'best'}
# 0.753 (+/-0.080) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 2, 'splitter': 'random'}
# 0.765 (+/-0.084) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'best'}
# 0.828 (+/-0.079) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'random'}
# 0.775 (+/-0.092) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 8, 'splitter': 'best'}
# 0.785 (+/-0.133) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 8, 'splitter': 'random'}
# 0.752 (+/-0.108) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 16, 'splitter': 'best'}
# 0.782 (+/-0.038) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 16, 'splitter': 'random'}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'best'}
# 0.792 (+/-0.075) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'random'}
# 0.752 (+/-0.088) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'best'}
# 0.779 (+/-0.124) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'random'}
# 0.772 (+/-0.070) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'best'}
# 0.769 (+/-0.035) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'random'}
# 0.759 (+/-0.070) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'best'}
# 0.769 (+/-0.091) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'random'}
# 0.755 (+/-0.100) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'best'}
# 0.812 (+/-0.087) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'random'}
# 0.792 (+/-0.071) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'best'}
# 0.746 (+/-0.084) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'random'}
# 0.762 (+/-0.109) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'best'}
# 0.768 (+/-0.136) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'random'}
# 0.755 (+/-0.088) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'best'}
# 0.759 (+/-0.101) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'random'}
# 0.769 (+/-0.075) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'best'}
# 0.736 (+/-0.059) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'random'}
# 0.752 (+/-0.108) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'best'}
# 0.779 (+/-0.056) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'random'}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'best'}
# 0.776 (+/-0.077) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'random'}
# 0.766 (+/-0.088) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'best'}
# 0.749 (+/-0.084) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'random'}
# 0.752 (+/-0.101) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'best'}
# 0.746 (+/-0.114) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'random'}
# 0.766 (+/-0.072) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'best'}
# 0.752 (+/-0.024) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'random'}
# 0.755 (+/-0.100) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'best'}
# 0.765 (+/-0.091) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'random'}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'best'}
# 0.776 (+/-0.110) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'random'}
# 0.795 (+/-0.115) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'best'}
# 0.795 (+/-0.072) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'random'}
# 0.795 (+/-0.115) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'best'}
# 0.792 (+/-0.077) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'random'}
# 0.795 (+/-0.105) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'best'}
# 0.798 (+/-0.063) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'random'}
# 0.779 (+/-0.121) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'best'}
# 0.766 (+/-0.088) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'random'}
# 0.792 (+/-0.071) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'best'}
# 0.762 (+/-0.110) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'random'}
# 0.769 (+/-0.077) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 2, 'splitter': 'best'}
# 0.769 (+/-0.130) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 2, 'splitter': 'random'}
# 0.765 (+/-0.084) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'best'}
# 0.809 (+/-0.059) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'random'}
# 0.762 (+/-0.100) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 8, 'splitter': 'best'}
# 0.769 (+/-0.101) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 8, 'splitter': 'random'}
# 0.755 (+/-0.100) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 16, 'splitter': 'best'}
# 0.779 (+/-0.109) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 16, 'splitter': 'random'}
# 0.792 (+/-0.071) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'best'}
# 0.789 (+/-0.033) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'random'}
# 0.759 (+/-0.116) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'best'}
# 0.749 (+/-0.105) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'random'}
# 0.759 (+/-0.101) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'best'}
# 0.795 (+/-0.075) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'random'}
# 0.765 (+/-0.085) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'best'}
# 0.765 (+/-0.143) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'random'}
# 0.755 (+/-0.100) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'best'}
# 0.766 (+/-0.053) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'random'}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'best'}
# 0.766 (+/-0.102) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'random'}
# 0.769 (+/-0.106) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'best'}
# 0.779 (+/-0.076) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'random'}
# 0.756 (+/-0.103) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'best'}
# 0.703 (+/-0.103) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'random'}
# 0.765 (+/-0.079) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'best'}
# 0.726 (+/-0.067) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'random'}
# 0.752 (+/-0.108) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'best'}
# 0.782 (+/-0.082) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'random'}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'best'}
# 0.789 (+/-0.099) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'random'}
# 0.749 (+/-0.076) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'best'}
# 0.739 (+/-0.086) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'random'}
# 0.736 (+/-0.093) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'best'}
# 0.782 (+/-0.092) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'random'}
# 0.749 (+/-0.089) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'best'}
# 0.812 (+/-0.075) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'random'}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'best'}
# 0.759 (+/-0.067) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'best'}
# 0.798 (+/-0.089) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'random'}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'best'}
# 0.778 (+/-0.130) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'random'}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'best'}
# 0.802 (+/-0.086) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'random'}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'best'}
# 0.762 (+/-0.054) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'random'}
# 0.788 (+/-0.120) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'best'}
# 0.785 (+/-0.038) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'best'}
# 0.776 (+/-0.076) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'random'}
# 0.759 (+/-0.105) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 2, 'splitter': 'best'}
# 0.769 (+/-0.115) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 2, 'splitter': 'random'}
# 0.762 (+/-0.117) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'best'}
# 0.759 (+/-0.099) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'random'}
# 0.766 (+/-0.093) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 8, 'splitter': 'best'}
# 0.769 (+/-0.096) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 8, 'splitter': 'random'}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 16, 'splitter': 'best'}
# 0.812 (+/-0.078) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'best'}
# 0.779 (+/-0.077) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'random'}
# 0.769 (+/-0.111) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'best'}
# 0.766 (+/-0.052) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'random'}
# 0.742 (+/-0.118) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'best'}
# 0.776 (+/-0.077) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'random'}
# 0.752 (+/-0.109) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'best'}
# 0.792 (+/-0.115) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'random'}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'best'}
# 0.805 (+/-0.130) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'best'}
# 0.759 (+/-0.068) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'random'}
# 0.765 (+/-0.093) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'best'}
# 0.726 (+/-0.125) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'random'}
# 0.729 (+/-0.117) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'best'}
# 0.732 (+/-0.177) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'random'}
# 0.749 (+/-0.120) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'best'}
# 0.762 (+/-0.076) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'random'}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'best'}
# 0.769 (+/-0.070) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'best'}
# 0.775 (+/-0.061) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'best'}
# 0.759 (+/-0.094) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'best'}
# 0.799 (+/-0.040) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'best'}
# 0.802 (+/-0.068) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'best'}
# 0.723 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'best'}
# 0.759 (+/-0.058) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'best'}
# 0.759 (+/-0.108) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'best'}
# 0.792 (+/-0.051) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'best'}
# 0.779 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'best'}
# 0.752 (+/-0.120) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'best'}
# 0.772 (+/-0.113) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 2, 'splitter': 'best'}
# 0.789 (+/-0.077) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 2, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'best'}
# 0.785 (+/-0.087) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 8, 'splitter': 'best'}
# 0.772 (+/-0.082) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 8, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 16, 'splitter': 'best'}
# 0.812 (+/-0.078) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'best'}
# 0.782 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'best'}
# 0.788 (+/-0.110) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'best'}
# 0.802 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'best'}
# 0.792 (+/-0.077) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'best'}
# 0.792 (+/-0.083) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'best'}
# 0.779 (+/-0.070) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'best'}
# 0.772 (+/-0.074) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'best'}
# 0.762 (+/-0.046) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'best'}
# 0.782 (+/-0.026) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'best'}
# 0.765 (+/-0.067) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'best'}
# 0.795 (+/-0.067) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'random'}
# 0.769 (+/-0.105) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'best'}
# 0.782 (+/-0.084) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'random'}
# 0.756 (+/-0.146) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'best'}
# 0.755 (+/-0.108) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'random'}
# 0.756 (+/-0.146) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'best'}
# 0.762 (+/-0.077) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'random'}
# 0.762 (+/-0.101) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'best'}
# 0.789 (+/-0.092) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'best'}
# 0.766 (+/-0.059) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'random'}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'best'}
# 0.779 (+/-0.115) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'random'}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'best'}
# 0.782 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'random'}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'best'}
# 0.772 (+/-0.079) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'random'}
# 0.788 (+/-0.120) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'best'}
# 0.792 (+/-0.146) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'best'}
# 0.776 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'random'}
# ...
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'best'}
# 0.822 (+/-0.059) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'random'}
# 0.775 (+/-0.105) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'best'}
# 0.795 (+/-0.086) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'random'}
# 0.769 (+/-0.114) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'best'}
# 0.775 (+/-0.104) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'random'}
# 0.762 (+/-0.148) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'best'}
# 0.789 (+/-0.081) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'random'}
# 0.762 (+/-0.101) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'best'}
# 0.795 (+/-0.118) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'best'}
# 0.749 (+/-0.068) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'random'}
# 0.759 (+/-0.146) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'best'}
# 0.779 (+/-0.132) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'random'}
# 0.769 (+/-0.138) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'best'}
# 0.799 (+/-0.096) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'random'}
# 0.762 (+/-0.144) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'best'}
# 0.759 (+/-0.051) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'random'}
# 0.762 (+/-0.101) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'best'}
# 0.808 (+/-0.076) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'best'}
# 0.759 (+/-0.071) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'random'}
# 0.749 (+/-0.117) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'best'}
# 0.739 (+/-0.041) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'random'}
# 0.742 (+/-0.104) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'best'}
# 0.822 (+/-0.067) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'random'}
# 0.759 (+/-0.090) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'best'}
# 0.769 (+/-0.094) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'random'}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'best'}
# 0.799 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'best'}
# 0.808 (+/-0.110) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'random'}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'best'}
# 0.775 (+/-0.118) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'random'}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'best'}
# 0.785 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'random'}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'best'}
# 0.752 (+/-0.084) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'random'}
# 0.788 (+/-0.120) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'best'}
# 0.785 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'best'}
# 0.753 (+/-0.181) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'random'}
# 0.769 (+/-0.110) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 2, 'splitter': 'best'}
# 0.772 (+/-0.088) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 2, 'splitter': 'random'}
# 0.765 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'best'}
# 0.752 (+/-0.070) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'random'}
# 0.766 (+/-0.093) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 8, 'splitter': 'best'}
# 0.808 (+/-0.064) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 8, 'splitter': 'random'}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 16, 'splitter': 'best'}
# 0.776 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'best'}
# 0.775 (+/-0.136) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'random'}
# 0.746 (+/-0.073) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'best'}
# 0.776 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'random'}
# 0.752 (+/-0.074) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'best'}
# 0.785 (+/-0.087) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'random'}
# 0.759 (+/-0.085) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'best'}
# 0.756 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'random'}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'best'}
# 0.759 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'best'}
# 0.739 (+/-0.105) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'random'}
# 0.749 (+/-0.091) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'best'}
# 0.776 (+/-0.046) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'random'}
# 0.742 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'best'}
# 0.746 (+/-0.071) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'random'}
# 0.746 (+/-0.095) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'best'}
# 0.756 (+/-0.077) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'random'}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'best'}
# 0.779 (+/-0.052) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'best'}
# 0.779 (+/-0.127) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'random'}
# 0.752 (+/-0.099) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'best'}
# 0.775 (+/-0.077) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 2, 'splitter': 'random'}
# 0.742 (+/-0.088) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'best'}
# 0.736 (+/-0.073) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 4, 'splitter': 'random'}
# 0.739 (+/-0.110) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'best'}
# 0.779 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 8, 'splitter': 'random'}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'best'}
# 0.775 (+/-0.077) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'best'}
# 0.779 (+/-0.123) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 32, 'splitter': 'random'}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'best'}
# 0.762 (+/-0.070) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 2, 'splitter': 'random'}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'best'}
# 0.789 (+/-0.118) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 4, 'splitter': 'random'}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'best'}
# 0.759 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 8, 'splitter': 'random'}
# 0.788 (+/-0.120) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'best'}
# 0.802 (+/-0.057) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'best'}
# 0.785 (+/-0.068) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 32, 'splitter': 'random'}
# 0.769 (+/-0.110) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 2, 'splitter': 'best'}
# 0.815 (+/-0.065) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 2, 'splitter': 'random'}
# 0.759 (+/-0.105) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'best'}
# 0.799 (+/-0.112) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 4, 'splitter': 'random'}
# 0.766 (+/-0.093) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 8, 'splitter': 'best'}
# 0.782 (+/-0.058) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 8, 'splitter': 'random'}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 16, 'splitter': 'best'}
# 0.739 (+/-0.074) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'best'}
# 0.766 (+/-0.032) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 32, 'splitter': 'random'}
# 0.739 (+/-0.113) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'best'}
# 0.763 (+/-0.051) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 2, 'splitter': 'random'}
# 0.742 (+/-0.082) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'best'}
# 0.756 (+/-0.106) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 4, 'splitter': 'random'}
# 0.752 (+/-0.085) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'best'}
# 0.776 (+/-0.080) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 8, 'splitter': 'random'}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'best'}
# 0.772 (+/-0.074) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'best'}
# 0.789 (+/-0.088) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 32, 'splitter': 'random'}
# 0.762 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'best'}
# 0.749 (+/-0.094) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 2, 'splitter': 'random'}
# 0.742 (+/-0.135) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'best'}
# 0.759 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 4, 'splitter': 'random'}
# 0.739 (+/-0.118) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'best'}
# 0.736 (+/-0.070) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 8, 'splitter': 'random'}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'best'}
# 0.769 (+/-0.103) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 16, 'splitter': 'random'}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'best'}
# 0.788 (+/-0.090) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 32, 'splitter': 'random'}

# %%
print(grid_tree.cv_results_.keys())
# Out:
# 18

# %%
results_df = pd.DataFrame({
    'mean_test_score': grid_tree.cv_results_['mean_test_score'],
})

params_df = pd.DataFrame(grid_tree.cv_results_['params'], columns=grid_tree.cv_results_['params'][0].keys())

all_results = pd.concat([results_df, params_df], axis=1).sort_values('mean_test_score', ascending=False)

# Lets filter out the ones with nans, then list them!
# (36 is the total number of models, so I know 36 is enough to display them all.)
all_results.dropna().head(5)
# Out:
#      mean_test_score criterion  max_depth  max_leaf_nodes  min_samples_split  \
# 173         0.828415      gini       10.0            20.0                  4
# 379         0.821585   entropy        5.0            20.0                 32
# 488         0.815027   entropy       20.0            40.0                 32
# 398         0.815027   entropy        5.0            80.0                 32
# 388         0.815027   entropy        5.0            40.0                 32
#
#     splitter
# 173   random
# 379   random
# 488     best
# 398     best
# 388     best

# %%
all_results.dropna().tail(5)
# Out:
#      mean_test_score criterion  max_depth  max_leaf_nodes  min_samples_split  \
# 494         0.738962   entropy       20.0            80.0                  8
# 195         0.735956      gini       10.0            80.0                  8
# 495         0.735902   entropy       20.0            80.0                  8
# 245         0.725902      gini       20.0            80.0                  8
# 243         0.702678      gini       20.0            80.0                  4
#
#     splitter
# 494     best
# 195   random
# 495   random
# 245   random
# 243   random

# %%
from sklearn.ensemble import RandomForestClassifier

tuned_parameters = {
    'n_estimators': [10, 100, 200, 500],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 3, 5, 10, 20],
    'min_samples_split': [2, 4, 8, 16, 32],
    'max_leaf_nodes': [None, 10, 40, 80],
    'n_jobs': [-1]
}

model = RandomForestClassifier()
grid_tree = GridSearchCV(model, tuned_parameters)
grid_tree.fit(input_data, labels)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 3, 5, 10, 20],
#                          'max_leaf_nodes': [None, 10, 40, 80],
#                          'min_samples_split': [2, 4, 8, 16, 32],
#                          'n_estimators': [10, 100, 200, 500], 'n_jobs': [-1]})
